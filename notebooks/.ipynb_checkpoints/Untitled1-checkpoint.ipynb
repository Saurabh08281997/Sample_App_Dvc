# %%
pwd
# Out:
# 'C:\\Users\\dell\\Desktop\\Ineuron\\MLOPS\\Sample_App\\notebooks'

# %%
from src.get_data import read_params
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os

os.chdir('C:\\Users\\dell\\Desktop\\Ineuron\\MLOPS\\Sample_App')


def log_production_model(config_path):
    config = read_params(config_path)
    
    
    mlflow_config = config["mlflow_config"] 
    

    model_name = mlflow_config["registered_model_name"]


    remote_server_uri = mlflow_config["remote_server_uri"]

    mlflow.set_tracking_uri(remote_server_uri)
    
    
    runs = mlflow.search_runs(experiment_ids=1)
    lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
    lowest_run_id = runs[runs["metrics.mae"] == lowest]["run_id"][0]
    

    client = MlflowClient()
    for mv in client.search_model_versions(f"name='{model_name}'"):
        mv = dict(mv)
        pprint(mv, indent=4)
        
#         if mv["run_id"] == lowest_run_id:
#             current_version = mv["version"]
#             logged_model = mv["source"]
#             pprint(mv, indent=4)
#             client.transition_model_version_stage(
#                 name=model_name,
#                 version=current_version,
#                 stage="Production"
#             )
#         else:
#             current_version = mv["version"]
#             client.transition_model_version_stage(
#                 name=model_name,
#                 version=current_version,
#                 stage="Staging"
#             )        


#     loaded_model = mlflow.pyfunc.load_model(logged_model)
    
#     model_path = config["webapp_model_dir"] #"prediction_service/model"

#     joblib.dump(loaded_model, model_path)

log_production_model("params.yaml")
# Out:
# {   'creation_timestamp': 1661828207833,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1661831422957,
#     'name': 'ElasticNetWineModel',
#     'run_id': '2cb4dbe1476b41229da9cb0b44947ad7',
#     'run_link': '',
#     'source': './artifacts/1/2cb4dbe1476b41229da9cb0b44947ad7/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '1'}
# {   'creation_timestamp': 1661828240165,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1661831423173,
#     'name': 'ElasticNetWineModel',
#     'run_id': '3b491e4ea47e4538abfa1d4608e347b1',
#     'run_link': '',
#     'source': './artifacts/1/3b491e4ea47e4538abfa1d4608e347b1/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '2'}
# {   'creation_timestamp': 1661828676082,
#     'current_stage': 'Staging',
#     'description': '',
#     'last_updated_timestamp': 1661831423337,
#     'name': 'ElasticNetWineModel',
#     'run_id': '37bdcb89a7294c239aae1b2ec15eb857',
#     'run_link': '',
#     'source': './artifacts/1/37bdcb89a7294c239aae1b2ec15eb857/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '3'}
# {   'creation_timestamp': 1661828731636,
#     'current_stage': 'Production',
#     'description': '',
#     'last_updated_timestamp': 1661831423981,
#     'name': 'ElasticNetWineModel',
#     'run_id': '235c34b24a3f43138721d7a6e0f8bdf3',
#     'run_link': '',
#     'source': './artifacts/1/235c34b24a3f43138721d7a6e0f8bdf3/artifacts/model',
#     'status': 'READY',
#     'status_message': '',
#     'tags': {},
#     'user_id': '',
#     'version': '4'}

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is EAD2-BD9B
#
#  Directory of C:\Users\dell\Desktop\Ineuron\MLOPS\Sample_App
#
# 08/30/2022  09:24 AM    <DIR>          .
# 08/30/2022  09:24 AM    <DIR>          ..
# 08/24/2022  08:19 PM    <DIR>          .dvc
# 08/24/2022  08:15 PM               142 .dvcignore
# 08/27/2022  05:03 PM    <DIR>          .github
# 08/24/2022  08:05 PM                 0 .gitignore
# 08/30/2022  09:37 AM    <DIR>          .idea
# 08/26/2022  08:56 AM    <DIR>          .pytest_cache
# 08/30/2022  09:24 AM    <DIR>          .tox
# 08/29/2022  09:07 AM             1,176 app.py
# 08/30/2022  08:26 AM    <DIR>          artifacts
# 08/27/2022  08:06 AM    <DIR>          build
# 08/24/2022  08:05 PM    <DIR>          data
# 08/24/2022  08:19 PM    <DIR>          data_given
# 08/30/2022  09:20 AM             1,789 dvc.lock
# 08/30/2022  09:15 AM             1,079 dvc.yaml
# 08/30/2022  09:20 AM           118,784 mlflow.db
# 08/30/2022  08:06 AM    <DIR>          mlruns
# 08/30/2022  09:39 AM    <DIR>          notebooks
# 08/30/2022  08:35 AM               855 params.yaml
# 08/29/2022  07:58 PM    <DIR>          prediction_service
# 08/27/2022  05:26 PM                20 Procfile
# 08/30/2022  08:30 AM             1,159 README.md
# 08/25/2022  07:33 PM    <DIR>          report
# 08/30/2022  07:49 AM               136 requirements.txt
# 08/25/2022  07:33 PM    <DIR>          saved_models
# 08/27/2022  08:03 AM               218 setup.py
# 08/30/2022  09:17 AM    <DIR>          src
# 08/30/2022  09:34 AM    <DIR>          src.egg-info
# 08/24/2022  08:05 PM               463 template.py
# 08/29/2022  07:59 PM    <DIR>          tests
# 08/27/2022  09:20 AM               431 tox.ini
# 08/27/2022  09:41 AM    <DIR>          webapp
#               13 File(s)        126,252 bytes
#               20 Dir(s)  18,469,801,984 bytes free
